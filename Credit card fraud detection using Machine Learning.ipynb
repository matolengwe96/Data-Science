# %% [markdown]
# ## Import necessary data

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("C:/Users/josep/Downloads/archive (6)/creditcard.csv")

# %% [markdown]
# ## View data

# %%
df.head(20)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
df.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284797 -1.343668  0.929369 -0.206210  0.106234  ... -0.228876 -0.514376
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Check if there is no missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].nunique() #Checking if there's only 2 outputs
# Out:
# 2

# %%
df['Amount'].mean()
# Out:
# 88.34961925093133

# %%
df.describe() # check descriptive stats
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
print(df['Class']) #target
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
df['Class'].sum() #Calculate number of fraudulent transactions
# Out:
# 492

# %%
df['Class'].sum() /df['Class'].shape[0] * 100 # checking percentage of fraudulent
# Out:
# 0.1727485630620034

# %% [markdown]
# ## EDA

# %%
import seaborn as sns

# %%
sns.distplot(df['Amount']) # checking normality
# Out:
# C:\Users\josep\AppData\Local\Temp\ipykernel_12752\2945972173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'])
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
sns.scatterplot(df['Amount']) #checking outliers that could be the fraudulent transactions
# Out:
# <Axes: ylabel='Amount'>

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ## The credit card data is highly unbalanced
#
# ##### Normal transaction is 0
# #### fraudulent transaction is 1

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Balance dataset

# %%
legit_sample = legit.sample(n =492)

# %%
#concatenate the legit sample with the fraud dataset 
#datasets must have equal priors

# %%
balanced_df = pd.concat([legit_sample,fraud], axis = 0)

# %%
balanced_df.head()
# Out:
#             Time        V1        V2        V3        V4         V5        V6  \
# 7705     10712.0 -0.848869 -0.373764  2.977380  0.149160  -0.686616  0.840114
# 65112    51434.0 -1.413719 -0.484431  0.411232 -1.723600   0.748871 -0.885473
# 263476  160976.0 -0.414917  1.048276 -0.957855 -1.426345   1.103619 -0.616559
# 84440    60305.0 -3.929906 -0.368906 -3.561828  2.161113 -11.614393  6.262317
# 222961  143194.0 -0.420301  1.049012 -1.088375  0.083486   0.007686 -0.893504
#
#                V7        V8        V9  ...       V21       V22       V23  \
# 7705    -0.915745  0.585830  2.724817  ...  0.081524  0.717807 -0.110086
# 65112    0.003919  0.170140 -1.754781  ...  0.381157  0.808584 -0.437938
# 263476   0.747796  0.437498 -0.348914  ... -0.117786 -0.551635  0.209731
# 84440   10.082224 -0.708029 -0.946186  ... -0.881913  0.227996  0.117186
# 222961   0.097646  0.619965 -0.388255  ...  0.178774  0.458291  0.404794
#
# ...

# %%
balanced_df.shape
# Out:
# (984, 31)

# %%
balanced_df['Class'].sum()
# Out:
# 492

# %%
balanced_df['Class'].sum()/balanced_df.shape[0]
# Out:
# 0.5

# %%
balanced_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting data into Features and targets

# %%
X = balanced_df.drop(columns = 'Class', axis = 1)

# %%
X.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
y = balanced_df['Class']

# %%
y
# Out:
# 7705      0
# 65112     0
# 263476    0
# 84440     0
# 222961    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, stratify = y, random_state =  2)

# %%
X_train.shape, X_test.shape,y_train.shape,y_test.shape
# Out:
# ((787, 30), (197, 30), (787,), (197,))

# %% [markdown]
# ### Model Training

# %%
## Logestic regression to classify into binary of yes or no for fraud detection
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Model Evaluation
# ###### Accuracy score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,y_train)

# %%
print("Accuracy on training data",training_data_accuracy)
# Out:
# Accuracy on training data 0.9440914866581956

# %% [markdown]
# ## Accuracy on test data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,y_test)

# %%
print("Accuracy on test data",test_data_accuracy)
# Out:
# Accuracy on test data 0.9441624365482234
